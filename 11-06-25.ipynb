# %% [markdown]
# #  Introduction to seaborn

# %%
import seaborn as sns

# %%
# scatterplot
# line plot

# %%
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('tips')

# %%
df.head()   # used to print topmost 5 rows
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
insights = as bill increases the tip also increases

# %%
Relationship between Total Bill and Tip

one data point tales about one customer

#Relate every data paint to the dato

#Insight

#a) As the bill increase Tips also increases

2) Majority of the customers are paying total bilt and tip between 105 to 255 roughly


tips are always less than total bill

# %%
sns.scatterplot(data=df,x='total_bill',y='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex',size='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
ax=sns.scatterplot(data=df,x="total_bill",y='tip')

ax.set_title('scatterplot total_bill vs tip')
ax.set_xlabel('total bill')
ax.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df2=sns.load_dataset('titanic')

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.scatterplot(data=df2,x="fare",y='age')
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.barplot(data=df2,x='sex',y='fare')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df3=sns.load_dataset('flights')

# %%
df3
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.barplot(data=df3,x='month',y='passengers')
# Out:
# <Axes: xlabel='month', ylabel='passengers'>
