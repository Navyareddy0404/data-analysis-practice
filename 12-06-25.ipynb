# %% [markdown]
# # pandas

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
#  load your dataset

df=pd.read_csv('onlinefoods.csv',encoding='latin-1')

# %%
df.sample(5)
# Out:
#      Age  Gender Marital Status  Occupation  Monthly Income  \
# 157   32  Female        Married  House wife       No Income
# 289   20  Female         Single     Student       No Income
# 344   26    Male         Single    Employee  10001 to 25000
# 8     23  Female         Single     Student       No Income
# 218   31  Female        Married  House wife       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 157                   Graduate            3   12.9850    77.5533    560010
# 289                   Graduate            2   13.0734    77.5464    560014
# 344                   Graduate            2   12.9217    77.5936    560041
# 8                Post Graduate            2   12.9766    77.5993    560001
# 218                   Graduate            5   13.0078    77.5577    560055
#
#     Output   Feedback Unnamed: 12
# 157    Yes   Positive         Yes
# 289    Yes   Positive         Yes
# 344     No  Negative           No
# ...

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
df.tail()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 383    Yes  Positive         Yes
# 384    Yes  Positive         Yes
# 385    Yes  Positive         Yes
# ...

# %%
df.sample()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 267   25  Female         Single   Employee  25001 to 50000
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 267              Post Graduate            2   12.9967    77.7582    560067
#
#     Output  Feedback Unnamed: 12
# 267    Yes  Positive         Yes

# %%
df.head(10)
# Out:
#    Age  Gender Marital Status Occupation   Monthly Income  \
# 0   20  Female         Single    Student        No Income
# 1   24  Female         Single    Student   Below Rs.10000
# 2   22    Male         Single    Student   Below Rs.10000
# 3   22  Female         Single    Student        No Income
# 4   22    Male         Single    Student   Below Rs.10000
# 5   27  Female        Married   Employee  More than 50000
# 6   22    Male         Single    Student        No Income
# 7   24  Female         Single    Student        No Income
# 8   23  Female         Single    Student        No Income
# 9   23  Female         Single    Student        No Income
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# ...

# %%
df.tail(10)
# Out:
#      Age  Gender Marital Status Occupation   Monthly Income  \
# 378   23  Female         Single   Employee   25001 to 50000
# 379   22    Male         Single    Student   Below Rs.10000
# 380   27  Female        Married   Employee  More than 50000
# 381   22    Male         Single    Student        No Income
# 382   24  Female         Single    Student        No Income
# 383   23  Female         Single    Student        No Income
# 384   23  Female         Single    Student        No Income
# 385   22  Female         Single    Student        No Income
# 386   23    Male         Single    Student   Below Rs.10000
# 387   23    Male         Single    Student        No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 378              Post Graduate            2   12.9847    77.5491    560100
# 379              Post Graduate            4   12.9850    77.5533    560010
# 380              Post Graduate            2   12.9299    77.6848    560103
# ...

# %%
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
df['Gender']
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 383    Female
# 384    Female
# 385    Female
# 386      Male
# 387      Male
# Name: Gender, Length: 388, dtype: object

# %%
df['Monthly Income']
# Out:
# 0           No Income
# 1      Below Rs.10000
# 2      Below Rs.10000
# 3           No Income
# 4      Below Rs.10000
#             ...
# 383         No Income
# 384         No Income
# 385         No Income
# 386    Below Rs.10000
# 387         No Income
# Name: Monthly Income, Length: 388, dtype: object

# %%
df['Feedback']
# Out:
# 0       Positive
# 1       Positive
# 2      Negative
# 3       Positive
# 4       Positive
#          ...
# 383     Positive
# 384     Positive
# 385     Positive
# 386     Positive
# 387     Positive
# Name: Feedback, Length: 388, dtype: object

# %%
df['Family size']
# Out:
# 0      4
# 1      3
# 2      3
# 3      6
# 4      4
#       ..
# 383    2
# 384    4
# 385    5
# 386    2
# 387    5
# Name: Family size, Length: 388, dtype: int64

# %%
df['Age']
# Out:
# 0      20
# 1      24
# 2      22
# 3      22
# 4      22
#        ..
# 383    23
# 384    23
# 385    22
# 386    23
# 387    23
# Name: Age, Length: 388, dtype: int64

# %%
df['Age'].head()
# Out:
# 0    20
# 1    24
# 2    22
# 3    22
# 4    22
# Name: Age, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
x=df['Age'].sample(5)

# %%
x
# Out:
# 172    27
# 378    23
# 249    23
# 32     25
# 374    21
# Name: Age, dtype: int64

# %%
df['Age'].sample(5)
# Out:
# 20     24
# 299    25
# 127    25
# 241    22
# 260    30
# Name: Age, dtype: int64

# %%
df.iloc[387]
# Out:
# Age                                      23
# Gender                                 Male
# Marital Status                       Single
# Occupation                          Student
# Monthly Income                    No Income
# Educational Qualifications    Post Graduate
# Family size                               5
# latitude                            12.8988
# longitude                           77.5764
# Pin code                             560078
# Output                                  Yes
# Feedback                           Positive
# Unnamed: 12                             Yes
# Name: 387, dtype: object

# %%
df.loc[1]
# Out:
# Age                                       24
# Gender                                Female
# Marital Status                        Single
# Occupation                           Student
# Monthly Income                Below Rs.10000
# Educational Qualifications          Graduate
# Family size                                3
# latitude                              12.977
# longitude                            77.5773
# Pin code                              560009
# Output                                   Yes
# Feedback                            Positive
# Unnamed: 12                              Yes
# Name: 1, dtype: object
